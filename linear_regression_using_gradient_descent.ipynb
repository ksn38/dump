# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#y = Ax + B
X = np.array([1, 1, 2, 5, 3, 0, 5, 10, 1, 2])
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

mse = []
n = len(X)

def calc_mse(y, y_pred):
    err =  1/n * sum((y_pred - y)**2) #== np.mean((y - y_pred)**2)
    return err
A = 5
B = 0
alpha = 0.005

for i in range(51):
    y_pred = A * X
    err = calc_mse(y, y_pred)
    mse.append(err)
    A -= alpha * ((-2/n) * sum(X * (y - y_pred))) #derivative from loss function
    B -= alpha * ((-2/n) * sum(y - y_pred))
    if i % 25 == 0:
        print(f'Iteration #{i}: W_new = {W}, B_new = {B}, MSE = {round(err,2)}')
# Out:
# Iteration #0: W_new = 11.76470588235306, B_new = 0.41500000000000004, MSE = 1777.5
# Iteration #25: W_new = 11.76470588235306, B_new = 6.697904851003677, MSE = 999.63
# Iteration #50: W_new = 11.76470588235306, B_new = 12.008682520910016, MSE = 999.56

# %%
plt.scatter(X, y)
plt.plot(W * np.arange(0,10) + B)

# %%
plt.plot(mse)
