# %%
from os import listdir
import os
import re
from pathlib import Path

# %%
mypath = 'F:\\Рисунки\\maps\\2015'
files = listdir(mypath)

'''for k in files:
    df = pd.read_csv(mypath + '/' + k)
    df.columns = ['tag', 'val']
    #df['norm_val'] = df.val/df.val.iloc[0]
    df['Date'] = re.findall('[0-9]{4}-[0-9]{2}-[0-9]{2}', k)[0]
    df[['Date', 'tag', 'val']].iloc[:299].to_csv('tags_for_PowerBI' + '/' + k, index=False, encoding='utf-8', sep=',')'''
    
print(files[0])
print(re.findall('\d+', files[0]))
x = re.findall('\d+', files[0])[0][1:]
print(x)

print(files[0][3:6])

for i in files:
    if i[3:6] == x:
        print(i)
        
paths = sorted(Path(mypath).iterdir(), key=os.path.getmtime)
print(f'{2:05d}.png')
# Out:
# 001000.png
# ['001000']
# 01000
# 000
# 00002.png

# %%
mypath = 'F:\\Рисунки\\maps\\north\\'
num = 1
for i in os.listdir(mypath):
    os.rename(mypath + i, mypath + str(f'{num:05d}') + '.png')
    num += 1

# %%
mypath = 'F:\\Рисунки\\maps\\2018(2)\\'
x = set()
num = 4553

for i in os.listdir(mypath):
    x.add(i[3:6])
    
xs = sorted(list(x))

# %%
mypath = 'F:\\Рисунки\\maps\\2018(2)\\'

num = 4553
for i in os.listdir(mypath):
    os.rename(mypath + i, mypath + str(f'{num:05d}') + '.png')
    num += 1

# %%
#2016 145-219-...-210
#2017 -275
#2018 276-014-...

for i in xs:
    os.rename(mypath + 'sp1' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
    os.rename(mypath + 'sp2' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
    os.rename(mypath + 'sp3' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
    os.rename(mypath + 'sp4' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-105f810c869b> in <module>
#       4
#       5 for i in xs:
# ----> 6     os.rename(mypath + 'sp1' + i + '.png', mypath + str(f'{num:05d}') + '.png')
#       7     num += 1
#       8     os.rename(mypath + 'sp2' + i + '.png', mypath + str(f'{num:05d}') + '.png')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'F:\\Рисунки\\maps\\2018(2)\\sp1mbs.png' -> 'F:\\Рисунки\\maps\\2018(2)\\05605.png'

# %%
xs[15]
# Out:
# '276'

# %%
mypath = 'F:\\Рисунки\\maps\\2015-2022\\0\\'
num = 11036
for i in sorted(Path(mypath).iterdir(), key=os.path.getmtime):
    os.rename(i, mypath + str(f'{num:05d}') + '.png')
    #print(i)
    num += 1

# %%
sorted(Path(mypath).iterdir(), key=os.path.getmtime)
# Out:
# [WindowsPath('F:/Рисунки/maps/2017/sp1211.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp2211.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp3211.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp4211.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp1212.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp2212.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp3212.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp4212.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp1213.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp2213.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp3213.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp4213.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp1214.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp2214.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp3214.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp4214.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp1215.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp2215.png'),
#  WindowsPath('F:/Рисунки/maps/2017/sp3215.png'),
# ...

# %%
for i in xs:
    os.rename(mypath + 'sp1' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
    os.rename(mypath + 'sp2' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
    os.rename(mypath + 'sp3' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
    os.rename(mypath + 'sp4' + i + '.png', mypath + str(f'{num:05d}') + '.png')
    num += 1
